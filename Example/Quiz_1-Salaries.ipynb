# %%
# Import libraries
import pandas as pd

# %%
# Import data
data = pd.read_csv('Input/Salaries.csv')

# %%
# Read the first 5 rows records
data.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
# Quiz 1
# Read the first 10 rows records
data.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
# Read the first 20 rows records
data.head(20)
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# ...

# %%
# Read the first 50 rows records
data.head(50)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
# Read the first 5 rows records from below
data.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
# 1. Group data using rank
data_rank = data.groupby(['rank'])

# 2. Calculate mean value for each numeric column per each group
data_rank.mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
# 3. Calculate mean salary for each professor rank
data.groupby('rank')[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %%
# 4. Calculate mean salary for each profressor rank
data.groupby(['rank'], sort = False)[['salary']].mean()
# Out:
#                   salary
# rank
# Prof       123624.804348
# AssocProf   91786.230769
# AsstProf    81362.789474

# %%
# 5. Calculate mean salary for each profressor rank
data_sub = data[data['salary'] > 120000]
data_sub.head()
# Out:
#     rank discipline  phd  service   sex  salary
# 0   Prof          B   56       49  Male  186960
# 3   Prof          A   40       31  Male  131205
# 5   Prof          A   20       20  Male  122400
# 7   Prof          A   18       18  Male  126300
# 10  Prof          B   39       33  Male  128250

# %%
# 6. Select only those rows that contain female profressors
data_f = data[data['sex'] == 'Female']
data_f.head()
# Out:
#          rank discipline  phd  service     sex  salary
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000

# %%
# 7. Select column salary
data['salary'].head()
# Out:
# 0    186960
# 1     93000
# 2    110515
# 3    131205
# 4    104800
# Name: salary, dtype: int64

# %%
# 8. Select column rank and salary
data[['rank', 'salary']].head()
# Out:
#    rank  salary
# 0  Prof  186960
# 1  Prof   93000
# 2  Prof  110515
# 3  Prof  131205
# 4  Prof  104800

# %%
# 9. Select rows by their position
data[10:20]
# Out:
#         rank discipline  phd  service   sex  salary
# 10      Prof          B   39       33  Male  128250
# 11      Prof          B   23       23  Male  134778
# 12  AsstProf          B    1        0  Male   88000
# 13      Prof          B   35       33  Male  162200
# 14      Prof          B   25       19  Male  153750
# 15      Prof          B   17        3  Male  150480
# 16  AsstProf          B    8        3  Male   75044
# 17  AsstProf          B    4        0  Male   92000
# 18      Prof          A   19        7  Male  107300
# 19      Prof          A   29       27  Male  150500

# %%
# 10. Select rows by thier labels
data_sub.loc[10:20, ['rank', 'sex', 'salary']]
# Out:
#     rank   sex  salary
# 10  Prof  Male  128250
# 11  Prof  Male  134778
# 13  Prof  Male  162200
# 14  Prof  Male  153750
# 15  Prof  Male  150480
# 19  Prof  Male  150500

# %%
# 11. Select rows by their labels
data_sub.iloc[10:20, [0, 3, 4, 5]]
# Out:
#     rank  service     sex  salary
# 26  Prof       19    Male  148750
# 27  Prof       43    Male  155865
# 29  Prof       20    Male  123683
# 31  Prof       21    Male  155750
# 35  Prof       23    Male  126933
# 36  Prof       45    Male  146856
# 39  Prof       18  Female  129000
# 40  Prof       36  Female  137000
# 44  Prof       19  Female  151768
# 45  Prof       25  Female  140096

# %%
# 12. Create a new data frane from the original sorted by the column Salary
data_sorted = data.sort_values(by = 'service')
data_sorted.head()
# Out:
#         rank discipline  phd  service     sex  salary
# 55  AsstProf          A    2        0  Female   72500
# 23  AsstProf          A    2        0    Male   85000
# 43  AsstProf          B    5        0  Female   77000
# 17  AsstProf          B    4        0    Male   92000
# 12  AsstProf          B    1        0    Male   88000

# %%
# 13. Sort data using 2 or more columns
data_sorted = data.sort_values(by = ['service', 'salary'], ascending = [True, False])
data_sorted.head(10)
# Out:
#         rank discipline  phd  service     sex  salary
# 52      Prof          A   12        0  Female  105000
# 17  AsstProf          B    4        0    Male   92000
# 12  AsstProf          B    1        0    Male   88000
# 23  AsstProf          A    2        0    Male   85000
# 43  AsstProf          B    5        0  Female   77000
# 55  AsstProf          A    2        0  Female   72500
# 57  AsstProf          A    3        1  Female   72500
# 28  AsstProf          B    7        2    Male   91300
# 42  AsstProf          B    4        2  Female   80225
# 68  AsstProf          A    4        2  Female   77500
